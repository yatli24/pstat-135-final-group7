# %% [markdown]
# **Introduction**

# %% [markdown]
# **Research Question**: In the state of Alaska, how do socioeconomic factors—such as estimated household income, ethnicity, gender, home value, education level, age, and occupation group—influence party affiliation?

# %% [markdown]
# Alaska joined the United States on January 3, 1959 becoming the 49th U.S. state. This state particiapted in its first presidential election in 1960 with three electoral votes. In 2020 Alaska has a population of 733,000 making it the least densely populated state. The state is composed of around 59% White, 15% Alaska Native, 6% Asian, 3% Black, 1.7% Pacific Islander, and ~7% Hispanic/Latino. Between 1960 and 2020 Alaska particiapted in 16 elections, voting Republican in 15 out of 16 and only once in 1964 voted Democrat.
#
# We will be looking at the trends in party affiliation over the past 16 elections in Alaska to determine what socioeconomic factors help to predict an individual's party. A few examples might be that Alaskans with higher median income levels especially those involved in the oil, or mining industry tend to lean Republican aligning with the pro-business and lower-tax policies. Additionally, Indigenous Alaskans which make up about 15-20% tend to support Democrats especially on issues related to environmental policies, and rural infrastructure. White Alaskans who make up the majority of the population have historically leaned Republican especially in suburban and rural counties. We will analyze the data to determine if other factors such as Education level, occupation, age, and average income level significantly affect party affiliation in Alaska.

# %% [markdown]
# **1. Data in Big Query**

# %% [markdown]
# **Part 1.2- Shell Script in Cloud**

# %%
'''
# Array of state codes
states=(
  AK AL AR AZ CO CT DC DE GA HI
  IA ID IL IN KS KY LA MA MD ME
  MI MN MO MS MT NC ND NE NH NJ
  NM NV OH OK OR RI SC SD TN UT
  VA VT WA WI WV WY
)

PROJECT="pstat-135-235-spring-2025"
DATASET="voterfile"

for state in "
{PROJECT}:
{state}"

  # Check if the table exists
  if bq ls "
{DATASET}" | awk '{print 1}' | grep -qw "
state"; then
    # Query row count and extract clean value
    ROWS=
{PROJECT}.
{state}\`" | tail -n 1)
    echo "
ROWS rows"
  else
    echo "$state: Error, unable to count rows"
  fi
done
'''

# %% [markdown]
# The script first defines an array of state codes, the project name, and dataset name. It loops through each state, checks if the state table exists, queries the row count, and prints the result.

# %% [markdown]
# ![](/Workspace/Users/karinaroddey@ucsb.edu/1.2-turnout-by-year-white-bg.png)

# %% [markdown]
# ![](/Workspace/Users/karinaroddey@ucsb.edu/1.2-turnout-by-year.png)

# %% [markdown]
# **1.3 Voter Turnout Query**

# %%
'''
SELECT
  2000 AS year,
  AVG(CASE WHEN General_2000 = 'Y' THEN 1.0 ELSE 0 END) AS turnout
FROM `pstat-135-235-spring-2025.voterfile.AK`

UNION ALL

SELECT
  2002 AS year,
  AVG(CASE WHEN General_2002 = 'Y' THEN 1.0 ELSE 0 END) AS turnout
FROM `pstat-135-235-spring-2025.voterfile.AK`

UNION ALL

SELECT
  2004 AS year,
  AVG(CASE WHEN General_2004 = 'Y' THEN 1.0 ELSE 0 END) AS turnout
FROM `pstat-135-235-spring-2025.voterfile.AK`

UNION ALL

SELECT
  2006 AS year,
  AVG(CASE WHEN General_2006 = 'Y' THEN 1.0 ELSE 0 END) AS turnout
FROM `pstat-135-235-spring-2025.voterfile.AK`

UNION ALL

SELECT
  2008 AS year,
  AVG(CASE WHEN General_2008 = 'Y' THEN 1.0 ELSE 0 END) AS turnout
FROM `pstat-135-235-spring-2025.voterfile.AK`

UNION ALL

SELECT
  2010 AS year,
  AVG(CASE WHEN General_2010 = 'Y' THEN 1.0 ELSE 0 END) AS turnout
FROM `pstat-135-235-spring-2025.voterfile.AK`

UNION ALL

SELECT
  2012 AS year,
  AVG(CASE WHEN General_2012 = 'Y' THEN 1.0 ELSE 0 END) AS turnout
FROM `pstat-135-235-spring-2025.voterfile.AK`

UNION ALL

SELECT
  2014 AS year,
  AVG(CASE WHEN General_2014 = 'Y' THEN 1.0 ELSE 0 END) AS turnout
FROM `pstat-135-235-spring-2025.voterfile.AK`

UNION ALL

SELECT
  2016 AS year,
  AVG(CASE WHEN General_2016 = 'Y' THEN 1.0 ELSE 0 END) AS turnout
FROM `pstat-135-235-spring-2025.voterfile.AK`

UNION ALL

SELECT
  2018 AS year,
  AVG(CASE WHEN General_2018 = 'Y' THEN 1.0 ELSE 0 END) AS turnout
FROM `pstat-135-235-spring-2025.voterfile.AK`

ORDER BY year;
'''

# %% [markdown]
# The SQL query returns two columns, year and turnout, which are the year and turnout rate respectively.

# %%
from pyspark.sql.functions import *
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
bucket_dir = 'gs://pstat135-voter-file/VM2Uniform/'
df= spark.read.parquet(bucket_dir + 'VM2Uniform--AK--2021-02-03')
df.head(20)
# Out:
# [Row(SEQUENCE='275346', LALVOTERID='LALAK176775952', Voters_Active='A', Voters_StateVoterID='00114975', Voters_CountyVoterID=None, VoterTelephones_LandlineAreaCode=None, VoterTelephones_Landline7Digit=None, VoterTelephones_LandlineFormatted=None, VoterTelephones_LandlineUnformatted=None, VoterTelephones_LandlineConfidenceCode=None, VoterTelephones_CellPhoneOnly=None, VoterTelephones_CellPhoneFormatted=None, VoterTelephones_CellPhoneUnformatted=None, VoterTelephones_CellConfidenceCode=None, Voters_FirstName='Chase', Voters_MiddleName=None, Voters_LastName='Hensel', Voters_NameSuffix=None, Residence_Addresses_AddressLine='1674 Red Fox Dr', Residence_Addresses_ExtraAddressLine=None, Residence_Addresses_City='Fairbanks', Residence_Addresses_State='AK', Residence_Addresses_Zip='99709', Residence_Addresses_ZipPlus4='6622', Residence_Addresses_HouseNumber='1674', Residence_Addresses_PrefixDirection=None, Residence_Addresses_StreetName='Red Fox', Residence_Addresses_Designator='Dr', Residence_Addresses_SuffixDirection=None, Residence_Addresses_ApartmentNum=None, Residence_Addresses_ApartmentType=None, Residence_Addresses_CassErrStatCode='S80000', Voters_SequenceZigZag='275345', Voters_SequenceOddEven='275343', Residence_Addresses_CensusTract='001300', Residence_Addresses_CensusBlockGroup='3', Residence_Addresses_CensusBlock='3000', Residence_Addresses_Latitude='64.899810', Residence_Addresses_Longitude='-147.808890', Residence_Addresses_LatLongAccuracy='GeoMatchRooftop', Residence_Addresses_Property_LandSq_Footage='0237000', Residence_Addresses_Property_HomeSq_Footage='01900', Residence_Addresses_Density='436', Residence_Families_FamilyID='R000167760', Residence_Families_HHCount='2', Residence_HHGender_Description='Mixed Gender Household', Residence_HHParties_Description='Democratic & Independent', Mailing_Addresses_AddressLine='1674 Red Fox Dr', Mailing_Addresses_ExtraAddressLine=None, Mailing_Addresses_City='Fairbanks', Mailing_Addresses_State='AK', Mailing_Addresses_Zip='99709', Mailing_Addresses_ZipPlus4='6622', Mailing_Addresses_HouseNumber='1674', Mailing_Addresses_PrefixDirection=None, Mailing_Addresses_StreetName='Red Fox', Mailing_Addresses_Designator='Dr', Mailing_Addresses_SuffixDirection=None, Mailing_Addresses_ApartmentNum=None, Mailing_Addresses_ApartmentType=None, Mailing_Addresses_CassErrStatCode='S80000', Mailing_Families_FamilyID='M000167760', Mailing_Families_HHCount='2', Mailing_HHGender_Description='Mixed Gender Household', Mailing_HHParties_Description='Democratic & Independent', Voters_Gender='M', Voters_Age='70', Voters_BirthDate='09/03/1951', DateConfidence_Description='Complete Date', Parties_Description='Non-Partisan', VoterParties_Change_Changed_Party=None, Ethnic_Description='German', EthnicGroups_EthnicGroup1Desc='European', CountyEthnic_LALEthnicCode=None, CountyEthnic_Description=None, Religions_Description='Protestant', Voters_CalculatedRegDate='06/05/1978', Voters_OfficialRegDate='07/10/2020', Voters_PlaceOfBirth=None, Languages_Description='English', AbsenteeTypes_Description=None, MilitaryStatus_Description=None, MaritalStatus_Description='Non-Traditional', US_Congressional_District='1', AddressDistricts_Change_Changed_CD='Has Not Changed Within Last 2 Years', State_Senate_District='B', AddressDistricts_Change_Changed_SD='Has Not Changed Within Last 2 Years', State_House_District='04', AddressDistricts_Change_Changed_HD='Has Not Changed Within Last 2 Years', State_Legislative_District=None, AddressDistricts_Change_Changed_LD=None, 2001_US_Congressional_District=None, 2001_State_Senate_District='D', 2001_State_House_District='07', 2001_State_Legislative_District=None, County='FAIRBANKS NORTH STAR', Voters_FIPS='090', AddressDistricts_Change_Changed_County='Has Not Changed Within Last 2 Years', Precinct='FARMERS LOOP (04-240)', County_Commissioner_District=None, County_Supervisorial_District=None, County_Legislative_District=None, City=None, City_Council_Commissioner_District=None, City_Ward=None, Cit ...
#  Row(SEQUENCE='275347', LALVOTERID='LALAK177125249', Voters_Active='A', Voters_StateVoterID='01011231', Voters_CountyVoterID=None, VoterTelephones_LandlineAreaCode=None, VoterTelephones_Landline7Digit=None, VoterTelephones_LandlineFormatted=None, VoterTelephones_LandlineUnformatted=None, VoterTelephones_LandlineConfidenceCode=None, VoterTelephones_CellPhoneOnly=None, VoterTelephones_CellPhoneFormatted=None, VoterTelephones_CellPhoneUnformatted=None, VoterTelephones_CellConfidenceCode=None, Voters_FirstName='Amelia', Voters_MiddleName='Cora', Voters_LastName='Boyd', Voters_NameSuffix=None, Residence_Addresses_AddressLine='1678 Red Fox Dr', Residence_Addresses_ExtraAddressLine=None, Residence_Addresses_City='Fairbanks', Residence_Addresses_State='AK', Residence_Addresses_Zip='99709', Residence_Addresses_ZipPlus4='6622', Residence_Addresses_HouseNumber='1678', Residence_Addresses_PrefixDirection=None, Residence_Addresses_StreetName='Red Fox', Residence_Addresses_Designator='Dr', Residence_Addresses_SuffixDirection=None, Residence_Addresses_ApartmentNum=None, Residence_Addresses_ApartmentType=None, Residence_Addresses_CassErrStatCode='S80000', Voters_SequenceZigZag='275346', Voters_SequenceOddEven='275344', Residence_Addresses_CensusTract='001300', Residence_Addresses_CensusBlockGroup='3', Residence_Addresses_CensusBlock='3000', Residence_Addresses_Latitude='64.899702', Residence_Addresses_Longitude='-147.808994', Residence_Addresses_LatLongAccuracy='GeoMatchRooftop', Residence_Addresses_Property_LandSq_Footage='0237000', Residence_Addresses_Property_HomeSq_Footage='01900', Residence_Addresses_Density='436', Residence_Families_FamilyID='R001866887', Residence_Families_HHCount='1', Residence_HHGender_Description='Female Only Household', Residence_HHParties_Description='Independent', Mailing_Addresses_AddressLine='1678 Red Fox Dr', Mailing_Addresses_ExtraAddressLine=None, Mailing_Addresses_City='Fairbanks', Mailing_Addresses_State='AK', Mailing_Addresses_Zip='99709', Mailing_Addresses_ZipPlus4='6622', Mailing_Addresses_HouseNumber='1678', Mailing_Addresses_PrefixDirection=None, Mailing_Addresses_StreetName='Red Fox', Mailing_Addresses_Designator='Dr', Mailing_Addresses_SuffixDirection=None, Mailing_Addresses_ApartmentNum=None, Mailing_Addresses_ApartmentType=None, Mailing_Addresses_CassErrStatCode='S80000', Mailing_Families_FamilyID='M001866887', Mailing_Families_HHCount='1', Mailing_HHGender_Description='Female Only Household', Mailing_HHParties_Description='Independent', Voters_Gender='F', Voters_Age=None, Voters_BirthDate=None, DateConfidence_Description=None, Parties_Description='Unknown', VoterParties_Change_Changed_Party=None, Ethnic_Description='Scots', EthnicGroups_EthnicGroup1Desc='European', CountyEthnic_LALEthnicCode=None, CountyEthnic_Description=None, Religions_Description=None, Voters_CalculatedRegDate='05/02/2008', Voters_OfficialRegDate='10/06/2020', Voters_PlaceOfBirth=None, Languages_Description=None, AbsenteeTypes_Description=None, MilitaryStatus_Description=None, MaritalStatus_Description=None, US_Congressional_District='1', AddressDistricts_Change_Changed_CD='Has Not Changed Within Last 2 Years', State_Senate_District='B', AddressDistricts_Change_Changed_SD='Within Last 6 Months', State_House_District='04', AddressDistricts_Change_Changed_HD='Within Last 6 Months', State_Legislative_District=None, AddressDistricts_Change_Changed_LD=None, 2001_US_Congressional_District=None, 2001_State_Senate_District='D', 2001_State_House_District='07', 2001_State_Legislative_District=None, County='FAIRBANKS NORTH STAR', Voters_FIPS='090', AddressDistricts_Change_Changed_County='Has Not Changed Within Last 2 Years', Precinct='FARMERS LOOP (04-240)', County_Commissioner_District=None, County_Supervisorial_District=None, County_Legislative_District=None, City=None, City_Council_Commissioner_District=None, City_Ward=None, City_Mayoral_District=None, Town_District=None, Town_Ward=None, Town_Council=None, Village=None, Village_Ward=N ...
#  Row(SEQUENCE='275348', LALVOTERID='LALAK176836796', Voters_Active='A', Voters_StateVoterID='00447409', Voters_CountyVoterID=None, VoterTelephones_LandlineAreaCode=None, VoterTelephones_Landline7Digit=None, VoterTelephones_LandlineFormatted=None, VoterTelephones_LandlineUnformatted=None, VoterTelephones_LandlineConfidenceCode=None, VoterTelephones_CellPhoneOnly='True', VoterTelephones_CellPhoneFormatted='(907) 306-2303', VoterTelephones_CellPhoneUnformatted='9073062303', VoterTelephones_CellConfidenceCode='1', Voters_FirstName='Leonie', Voters_MiddleName='H', Voters_LastName='Deramus', Voters_NameSuffix=None, Residence_Addresses_AddressLine='1696 Red Fox Dr', Residence_Addresses_ExtraAddressLine=None, Residence_Addresses_City='Fairbanks', Residence_Addresses_State='AK', Residence_Addresses_Zip='99709', Residence_Addresses_ZipPlus4='6622', Residence_Addresses_HouseNumber='1696', Residence_Addresses_PrefixDirection=None, Residence_Addresses_StreetName='Red Fox', Residence_Addresses_Designator='Dr', Residence_Addresses_SuffixDirection=None, Residence_Addresses_ApartmentNum=None, Residence_Addresses_ApartmentType=None, Residence_Addresses_CassErrStatCode='S80000', Voters_SequenceZigZag='275347', Voters_SequenceOddEven='275345', Residence_Addresses_CensusTract='001300', Residence_Addresses_CensusBlockGroup='3', Residence_Addresses_CensusBlock='3000', Residence_Addresses_Latitude='64.900520', Residence_Addresses_Longitude='-147.811220', Residence_Addresses_LatLongAccuracy='GeoMatchRooftop', Residence_Addresses_Property_LandSq_Footage='0217000', Residence_Addresses_Property_HomeSq_Footage='05500', Residence_Addresses_Density='436', Residence_Families_FamilyID='R000199577', Residence_Families_HHCount='1', Residence_HHGender_Description='Female Only Household', Residence_HHParties_Description='Democratic', Mailing_Addresses_AddressLine='1696 Red Fox Dr', Mailing_Addresses_ExtraAddressLine=None, Mailing_Addresses_City='Fairbanks', Mailing_Addresses_State='AK', Mailing_Addresses_Zip='99709', Mailing_Addresses_ZipPlus4='6622', Mailing_Addresses_HouseNumber='1696', Mailing_Addresses_PrefixDirection=None, Mailing_Addresses_StreetName='Red Fox', Mailing_Addresses_Designator='Dr', Mailing_Addresses_SuffixDirection=None, Mailing_Addresses_ApartmentNum=None, Mailing_Addresses_ApartmentType=None, Mailing_Addresses_CassErrStatCode='S80000', Mailing_Families_FamilyID='M000199577', Mailing_Families_HHCount='1', Mailing_HHGender_Description='Female Only Household', Mailing_HHParties_Description='Democratic', Voters_Gender='F', Voters_Age='72', Voters_BirthDate='03/31/1949', DateConfidence_Description='Complete Date', Parties_Description='Democratic', VoterParties_Change_Changed_Party=None, Ethnic_Description='French', EthnicGroups_EthnicGroup1Desc='European', CountyEthnic_LALEthnicCode=None, CountyEthnic_Description=None, Religions_Description='Catholic', Voters_CalculatedRegDate='09/21/1988', Voters_OfficialRegDate='08/12/2020', Voters_PlaceOfBirth=None, Languages_Description='English', AbsenteeTypes_Description=None, MilitaryStatus_Description=None, MaritalStatus_Description=None, US_Congressional_District='1', AddressDistricts_Change_Changed_CD='Has Not Changed Within Last 2 Years', State_Senate_District='B', AddressDistricts_Change_Changed_SD='Has Not Changed Within Last 2 Years', State_House_District='04', AddressDistricts_Change_Changed_HD='Has Not Changed Within Last 2 Years', State_Legislative_District=None, AddressDistricts_Change_Changed_LD=None, 2001_US_Congressional_District=None, 2001_State_Senate_District='D', 2001_State_House_District='07', 2001_State_Legislative_District=None, County='FAIRBANKS NORTH STAR', Voters_FIPS='090', AddressDistricts_Change_Changed_County='Has Not Changed Within Last 2 Years', Precinct='FARMERS LOOP (04-240)', County_Commissioner_District=None, County_Supervisorial_District=None, County_Legislative_District=None, City=None, City_Council_Commissioner_District=None, City_Ward=None, City_Mayoral_District=None,  ...
#  Row(SEQUENCE='275349', LALVOTERID='LALAK410115488', Voters_Active='A', Voters_StateVoterID='01128842', Voters_CountyVoterID=None, VoterTelephones_LandlineAreaCode=None, VoterTelephones_Landline7Digit=None, VoterTelephones_LandlineFormatted=None, VoterTelephones_LandlineUnformatted=None, VoterTelephones_LandlineConfidenceCode=None, VoterTelephones_CellPhoneOnly=None, VoterTelephones_CellPhoneFormatted=None, VoterTelephones_CellPhoneUnformatted=None, VoterTelephones_CellConfidenceCode=None, Voters_FirstName='Gordon', Voters_MiddleName='Robert', Voters_LastName='Haas', Voters_NameSuffix=None, Residence_Addresses_AddressLine='1697 Red Fox Dr', Residence_Addresses_ExtraAddressLine=None, Residence_Addresses_City='Fairbanks', Residence_Addresses_State='AK', Residence_Addresses_Zip='99709', Residence_Addresses_ZipPlus4='6623', Residence_Addresses_HouseNumber='1697', Residence_Addresses_PrefixDirection=None, Residence_Addresses_StreetName='Red Fox', Residence_Addresses_Designator='Dr', Residence_Addresses_SuffixDirection=None, Residence_Addresses_ApartmentNum=None, Residence_Addresses_ApartmentType=None, Residence_Addresses_CassErrStatCode='S80000', Voters_SequenceZigZag='275348', Voters_SequenceOddEven='275360', Residence_Addresses_CensusTract='001300', Residence_Addresses_CensusBlockGroup='3', Residence_Addresses_CensusBlock='3004', Residence_Addresses_Latitude='64.898850', Residence_Addresses_Longitude='-147.811820', Residence_Addresses_LatLongAccuracy='GeoMatchRooftop', Residence_Addresses_Property_LandSq_Footage='0158000', Residence_Addresses_Property_HomeSq_Footage='00400', Residence_Addresses_Density='161', Residence_Families_FamilyID='R000782749', Residence_Families_HHCount='1', Residence_HHGender_Description='Male Only Household', Residence_HHParties_Description='Independent', Mailing_Addresses_AddressLine='1697 Red Fox Dr', Mailing_Addresses_ExtraAddressLine=None, Mailing_Addresses_City='Fairbanks', Mailing_Addresses_State='AK', Mailing_Addresses_Zip='99709', Mailing_Addresses_ZipPlus4='6623', Mailing_Addresses_HouseNumber='1697', Mailing_Addresses_PrefixDirection=None, Mailing_Addresses_StreetName='Red Fox', Mailing_Addresses_Designator='Dr', Mailing_Addresses_SuffixDirection=None, Mailing_Addresses_ApartmentNum=None, Mailing_Addresses_ApartmentType=None, Mailing_Addresses_CassErrStatCode='S80000', Mailing_Families_FamilyID='M000782749', Mailing_Families_HHCount='1', Mailing_HHGender_Description='Male Only Household', Mailing_HHParties_Description='Independent', Voters_Gender='M', Voters_Age='59', Voters_BirthDate='07/01/1962', DateConfidence_Description='Complete Date', Parties_Description='Non-Partisan', VoterParties_Change_Changed_Party=None, Ethnic_Description='Dutch (Netherlands)', EthnicGroups_EthnicGroup1Desc='European', CountyEthnic_LALEthnicCode=None, CountyEthnic_Description=None, Religions_Description='Jewish', Voters_CalculatedRegDate='09/14/2012', Voters_OfficialRegDate='08/07/2020', Voters_PlaceOfBirth=None, Languages_Description='English', AbsenteeTypes_Description=None, MilitaryStatus_Description=None, MaritalStatus_Description=None, US_Congressional_District='1', AddressDistricts_Change_Changed_CD='Has Not Changed Within Last 2 Years', State_Senate_District='B', AddressDistricts_Change_Changed_SD='Has Not Changed Within Last 2 Years', State_House_District='04', AddressDistricts_Change_Changed_HD='Has Not Changed Within Last 2 Years', State_Legislative_District=None, AddressDistricts_Change_Changed_LD=None, 2001_US_Congressional_District=None, 2001_State_Senate_District='D', 2001_State_House_District='07', 2001_State_Legislative_District=None, County='FAIRBANKS NORTH STAR', Voters_FIPS='090', AddressDistricts_Change_Changed_County='Has Not Changed Within Last 2 Years', Precinct='FARMERS LOOP (04-240)', County_Commissioner_District=None, County_Supervisorial_District=None, County_Legislative_District=None, City=None, City_Council_Commissioner_District=None, City_Ward=None, City_Mayoral_District=None, Town_Dis ...
#  Row(SEQUENCE='275350', LALVOTERID='LALAK177038764', Voters_Active='A', Voters_StateVoterID='00898715', Voters_CountyVoterID=None, VoterTelephones_LandlineAreaCode=None, VoterTelephones_Landline7Digit=None, VoterTelephones_LandlineFormatted=None, VoterTelephones_LandlineUnformatted=None, VoterTelephones_LandlineConfidenceCode=None, VoterTelephones_CellPhoneOnly='True', VoterTelephones_CellPhoneFormatted='(907) 687-6309', VoterTelephones_CellPhoneUnformatted='9076876309', VoterTelephones_CellConfidenceCode='1', Voters_FirstName='Elizabeth', Voters_MiddleName='D', Voters_LastName='Jacobs', Voters_NameSuffix=None, Residence_Addresses_AddressLine='1707 Red Fox Dr', Residence_Addresses_ExtraAddressLine=None, Residence_Addresses_City='Fairbanks', Residence_Addresses_State='AK', Residence_Addresses_Zip='99709', Residence_Addresses_ZipPlus4='6666', Residence_Addresses_HouseNumber='1707', Residence_Addresses_PrefixDirection=None, Residence_Addresses_StreetName='Red Fox', Residence_Addresses_Designator='Dr', Residence_Addresses_SuffixDirection=None, Residence_Addresses_ApartmentNum=None, Residence_Addresses_ApartmentType=None, Residence_Addresses_CassErrStatCode='S80000', Voters_SequenceZigZag='275350', Voters_SequenceOddEven='275362', Residence_Addresses_CensusTract='001300', Residence_Addresses_CensusBlockGroup='3', Residence_Addresses_CensusBlock='3000', Residence_Addresses_Latitude='64.898591', Residence_Addresses_Longitude='-147.815081', Residence_Addresses_LatLongAccuracy='GeoMatchRooftop', Residence_Addresses_Property_LandSq_Footage='0479000', Residence_Addresses_Property_HomeSq_Footage='02800', Residence_Addresses_Density='436', Residence_Families_FamilyID='R001264450', Residence_Families_HHCount='2', Residence_HHGender_Description='Mixed Gender Household', Residence_HHParties_Description='Democratic & Independent', Mailing_Addresses_AddressLine='1707 Red Fox Dr', Mailing_Addresses_ExtraAddressLine=None, Mailing_Addresses_City='Fairbanks', Mailing_Addresses_State='AK', Mailing_Addresses_Zip='99709', Mailing_Addresses_ZipPlus4='6666', Mailing_Addresses_HouseNumber='1707', Mailing_Addresses_PrefixDirection=None, Mailing_Addresses_StreetName='Red Fox', Mailing_Addresses_Designator='Dr', Mailing_Addresses_SuffixDirection=None, Mailing_Addresses_ApartmentNum=None, Mailing_Addresses_ApartmentType=None, Mailing_Addresses_CassErrStatCode='S80000', Mailing_Families_FamilyID='M001265388', Mailing_Families_HHCount='2', Mailing_HHGender_Description='Mixed Gender Household', Mailing_HHParties_Description='Democratic & Independent', Voters_Gender='F', Voters_Age='51', Voters_BirthDate='07/21/1970', DateConfidence_Description='Complete Date', Parties_Description='Democratic', VoterParties_Change_Changed_Party=None, Ethnic_Description='English/Welsh', EthnicGroups_EthnicGroup1Desc='European', CountyEthnic_LALEthnicCode=None, CountyEthnic_Description=None, Religions_Description=None, Voters_CalculatedRegDate='11/20/2003', Voters_OfficialRegDate='08/07/2020', Voters_PlaceOfBirth=None, Languages_Description='English', AbsenteeTypes_Description=None, MilitaryStatus_Description=None, MaritalStatus_Description='Non-Traditional', US_Congressional_District='1', AddressDistricts_Change_Changed_CD='Has Not Changed Within Last 2 Years', State_Senate_District='B', AddressDistricts_Change_Changed_SD='Has Not Changed Within Last 2 Years', State_House_District='04', AddressDistricts_Change_Changed_HD='Has Not Changed Within Last 2 Years', State_Legislative_District=None, AddressDistricts_Change_Changed_LD=None, 2001_US_Congressional_District=None, 2001_State_Senate_District='D', 2001_State_House_District='07', 2001_State_Legislative_District=None, County='FAIRBANKS NORTH STAR', Voters_FIPS='090', AddressDistricts_Change_Changed_County='Has Not Changed Within Last 2 Years', Precinct='FARMERS LOOP (04-240)', County_Commissioner_District=None, County_Supervisorial_District=None, County_Legislative_District=None, City=None, City_Council_Commissioner_District=None ...
#  Row(SEQUENCE='275351', LALVOTERID='LALAK176844885', Voters_Active='A', Voters_StateVoterID='00411858', Voters_CountyVoterID=None, VoterTelephones_LandlineAreaCode=None, VoterTelephones_Landline7Digit=None, VoterTelephones_LandlineFormatted=None, VoterTelephones_LandlineUnformatted=None, VoterTelephones_LandlineConfidenceCode=None, VoterTelephones_CellPhoneOnly='True', VoterTelephones_CellPhoneFormatted='(323) 516-8111', VoterTelephones_CellPhoneUnformatted='3235168111', VoterTelephones_CellConfidenceCode='1', Voters_FirstName='Nathan', Voters_MiddleName='H', Voters_LastName='Collin', Voters_NameSuffix=None, Residence_Addresses_AddressLine='1707 Red Fox Dr', Residence_Addresses_ExtraAddressLine=None, Residence_Addresses_City='Fairbanks', Residence_Addresses_State='AK', Residence_Addresses_Zip='99709', Residence_Addresses_ZipPlus4='6666', Residence_Addresses_HouseNumber='1707', Residence_Addresses_PrefixDirection=None, Residence_Addresses_StreetName='Red Fox', Residence_Addresses_Designator='Dr', Residence_Addresses_SuffixDirection=None, Residence_Addresses_ApartmentNum=None, Residence_Addresses_ApartmentType=None, Residence_Addresses_CassErrStatCode='S80000', Voters_SequenceZigZag='275349', Voters_SequenceOddEven='275361', Residence_Addresses_CensusTract='001300', Residence_Addresses_CensusBlockGroup='3', Residence_Addresses_CensusBlock='3000', Residence_Addresses_Latitude='64.898591', Residence_Addresses_Longitude='-147.815081', Residence_Addresses_LatLongAccuracy='GeoMatchRooftop', Residence_Addresses_Property_LandSq_Footage='0479000', Residence_Addresses_Property_HomeSq_Footage='02800', Residence_Addresses_Density='436', Residence_Families_FamilyID='R001264450', Residence_Families_HHCount='2', Residence_HHGender_Description='Mixed Gender Household', Residence_HHParties_Description='Democratic & Independent', Mailing_Addresses_AddressLine='1707 Red Fox Dr', Mailing_Addresses_ExtraAddressLine=None, Mailing_Addresses_City='Fairbanks', Mailing_Addresses_State='AK', Mailing_Addresses_Zip='99709', Mailing_Addresses_ZipPlus4='6666', Mailing_Addresses_HouseNumber='1707', Mailing_Addresses_PrefixDirection=None, Mailing_Addresses_StreetName='Red Fox', Mailing_Addresses_Designator='Dr', Mailing_Addresses_SuffixDirection=None, Mailing_Addresses_ApartmentNum=None, Mailing_Addresses_ApartmentType=None, Mailing_Addresses_CassErrStatCode='S80000', Mailing_Families_FamilyID='M001265388', Mailing_Families_HHCount='2', Mailing_HHGender_Description='Mixed Gender Household', Mailing_HHParties_Description='Democratic & Independent', Voters_Gender='M', Voters_Age='62', Voters_BirthDate='01/30/1959', DateConfidence_Description='Complete Date', Parties_Description='Non-Partisan', VoterParties_Change_Changed_Party=None, Ethnic_Description='English/Welsh', EthnicGroups_EthnicGroup1Desc='European', CountyEthnic_LALEthnicCode=None, CountyEthnic_Description=None, Religions_Description=None, Voters_CalculatedRegDate='09/04/1987', Voters_OfficialRegDate='11/16/2020', Voters_PlaceOfBirth=None, Languages_Description=None, AbsenteeTypes_Description=None, MilitaryStatus_Description=None, MaritalStatus_Description='Non-Traditional', US_Congressional_District='1', AddressDistricts_Change_Changed_CD='Has Not Changed Within Last 2 Years', State_Senate_District='B', AddressDistricts_Change_Changed_SD='Has Not Changed Within Last 2 Years', State_House_District='04', AddressDistricts_Change_Changed_HD='Has Not Changed Within Last 2 Years', State_Legislative_District=None, AddressDistricts_Change_Changed_LD=None, 2001_US_Congressional_District=None, 2001_State_Senate_District='D', 2001_State_House_District='07', 2001_State_Legislative_District=None, County='FAIRBANKS NORTH STAR', Voters_FIPS='090', AddressDistricts_Change_Changed_County='Has Not Changed Within Last 2 Years', Precinct='FARMERS LOOP (04-240)', County_Commissioner_District=None, County_Supervisorial_District=None, County_Legislative_District=None, City=None, City_Council_Commissioner_District=None, City ...
#  Row(SEQUENCE='275352', LALVOTERID='LALAK177017449', Voters_Active='A', Voters_StateVoterID='00867394', Voters_CountyVoterID=None, VoterTelephones_LandlineAreaCode=None, VoterTelephones_Landline7Digit=None, VoterTelephones_LandlineFormatted=None, VoterTelephones_LandlineUnformatted=None, VoterTelephones_LandlineConfidenceCode=None, VoterTelephones_CellPhoneOnly=None, VoterTelephones_CellPhoneFormatted=None, VoterTelephones_CellPhoneUnformatted=None, VoterTelephones_CellConfidenceCode=None, Voters_FirstName='Gail', Voters_MiddleName=None, Voters_LastName='Norton', Voters_NameSuffix=None, Residence_Addresses_AddressLine='1710 Red Fox Dr', Residence_Addresses_ExtraAddressLine=None, Residence_Addresses_City='Fairbanks', Residence_Addresses_State='AK', Residence_Addresses_Zip='99709', Residence_Addresses_ZipPlus4='6665', Residence_Addresses_HouseNumber='1710', Residence_Addresses_PrefixDirection=None, Residence_Addresses_StreetName='Red Fox', Residence_Addresses_Designator='Dr', Residence_Addresses_SuffixDirection=None, Residence_Addresses_ApartmentNum=None, Residence_Addresses_ApartmentType=None, Residence_Addresses_CassErrStatCode='S80000', Voters_SequenceZigZag='275351', Voters_SequenceOddEven='275346', Residence_Addresses_CensusTract='001300', Residence_Addresses_CensusBlockGroup='3', Residence_Addresses_CensusBlock='3000', Residence_Addresses_Latitude='64.901470', Residence_Addresses_Longitude='-147.811690', Residence_Addresses_LatLongAccuracy='GeoMatchRooftop', Residence_Addresses_Property_LandSq_Footage='0099000', Residence_Addresses_Property_HomeSq_Footage='01000', Residence_Addresses_Density='436', Residence_Families_FamilyID='R001495834', Residence_Families_HHCount='1', Residence_HHGender_Description='Female Only Household', Residence_HHParties_Description='Independent', Mailing_Addresses_AddressLine='1710 Red Fox Dr', Mailing_Addresses_ExtraAddressLine=None, Mailing_Addresses_City='Fairbanks', Mailing_Addresses_State='AK', Mailing_Addresses_Zip='99709', Mailing_Addresses_ZipPlus4='6665', Mailing_Addresses_HouseNumber='1710', Mailing_Addresses_PrefixDirection=None, Mailing_Addresses_StreetName='Red Fox', Mailing_Addresses_Designator='Dr', Mailing_Addresses_SuffixDirection=None, Mailing_Addresses_ApartmentNum=None, Mailing_Addresses_ApartmentType=None, Mailing_Addresses_CassErrStatCode='S80000', Mailing_Families_FamilyID='M001495834', Mailing_Families_HHCount='1', Mailing_HHGender_Description='Female Only Household', Mailing_HHParties_Description='Independent', Voters_Gender='F', Voters_Age='37', Voters_BirthDate='11/27/1984', DateConfidence_Description='Complete Date', Parties_Description='Unknown', VoterParties_Change_Changed_Party=None, Ethnic_Description='English/Welsh', EthnicGroups_EthnicGroup1Desc='European', CountyEthnic_LALEthnicCode=None, CountyEthnic_Description=None, Religions_Description='Protestant', Voters_CalculatedRegDate='09/10/2002', Voters_OfficialRegDate='09/23/2020', Voters_PlaceOfBirth=None, Languages_Description='English', AbsenteeTypes_Description=None, MilitaryStatus_Description=None, MaritalStatus_Description=None, US_Congressional_District='1', AddressDistricts_Change_Changed_CD='Has Not Changed Within Last 2 Years', State_Senate_District='B', AddressDistricts_Change_Changed_SD='Has Not Changed Within Last 2 Years', State_House_District='04', AddressDistricts_Change_Changed_HD='Has Not Changed Within Last 2 Years', State_Legislative_District=None, AddressDistricts_Change_Changed_LD=None, 2001_US_Congressional_District=None, 2001_State_Senate_District='D', 2001_State_House_District='07', 2001_State_Legislative_District=None, County='FAIRBANKS NORTH STAR', Voters_FIPS='090', AddressDistricts_Change_Changed_County='Has Not Changed Within Last 2 Years', Precinct='FARMERS LOOP (04-240)', County_Commissioner_District=None, County_Supervisorial_District=None, County_Legislative_District=None, City=None, City_Council_Commissioner_District=None, City_Ward=None, City_Mayoral_District=None, Town_District=N ...
#  Row(SEQUENCE='275353', LALVOTERID='LALAK176747128', Voters_Active='A', Voters_StateVoterID='00033896', Voters_CountyVoterID=None, VoterTelephones_LandlineAreaCode=None, VoterTelephones_Landline7Digit=None, VoterTelephones_LandlineFormatted=None, VoterTelephones_LandlineUnformatted=None, VoterTelephones_LandlineConfidenceCode=None, VoterTelephones_CellPhoneOnly=None, VoterTelephones_CellPhoneFormatted=None, VoterTelephones_CellPhoneUnformatted=None, VoterTelephones_CellConfidenceCode=None, Voters_FirstName='Bruce', Voters_MiddleName='William', Voters_LastName='Foote', Voters_NameSuffix=None, Residence_Addresses_AddressLine='1712 Red Fox Dr', Residence_Addresses_ExtraAddressLine=None, Residence_Addresses_City='Fairbanks', Residence_Addresses_State='AK', Residence_Addresses_Zip='99709', Residence_Addresses_ZipPlus4=None, Residence_Addresses_HouseNumber='1712', Residence_Addresses_PrefixDirection=None, Residence_Addresses_StreetName='Red Fox', Residence_Addresses_Designator='Dr', Residence_Addresses_SuffixDirection=None, Residence_Addresses_ApartmentNum=None, Residence_Addresses_ApartmentType=None, Residence_Addresses_CassErrStatCode='E601', Voters_SequenceZigZag='275352', Voters_SequenceOddEven='275347', Residence_Addresses_CensusTract='001300', Residence_Addresses_CensusBlockGroup='3', Residence_Addresses_CensusBlock='3004', Residence_Addresses_Latitude='64.902541', Residence_Addresses_Longitude='-147.810748', Residence_Addresses_LatLongAccuracy='GeoMatchRooftop', Residence_Addresses_Property_LandSq_Footage=None, Residence_Addresses_Property_HomeSq_Footage=None, Residence_Addresses_Density='161', Residence_Families_FamilyID='R000348372', Residence_Families_HHCount='1', Residence_HHGender_Description='Male Only Household', Residence_HHParties_Description='Independent', Mailing_Addresses_AddressLine='PO Box 80809', Mailing_Addresses_ExtraAddressLine=None, Mailing_Addresses_City='Fairbanks', Mailing_Addresses_State='AK', Mailing_Addresses_Zip='99708', Mailing_Addresses_ZipPlus4='0809', Mailing_Addresses_HouseNumber=None, Mailing_Addresses_PrefixDirection=None, Mailing_Addresses_StreetName='PO Box 80809', Mailing_Addresses_Designator=None, Mailing_Addresses_SuffixDirection=None, Mailing_Addresses_ApartmentNum=None, Mailing_Addresses_ApartmentType=None, Mailing_Addresses_CassErrStatCode='S80000', Mailing_Families_FamilyID='M000284158', Mailing_Families_HHCount='2', Mailing_HHGender_Description='Mixed Gender Household', Mailing_HHParties_Description='Independent', Voters_Gender='M', Voters_Age='72', Voters_BirthDate='01/01/1949', DateConfidence_Description='Valid Year', Parties_Description='Unknown', VoterParties_Change_Changed_Party=None, Ethnic_Description='English/Welsh', EthnicGroups_EthnicGroup1Desc='European', CountyEthnic_LALEthnicCode=None, CountyEthnic_Description=None, Religions_Description='Catholic', Voters_CalculatedRegDate='02/24/1970', Voters_OfficialRegDate='07/18/2019', Voters_PlaceOfBirth=None, Languages_Description='English', AbsenteeTypes_Description=None, MilitaryStatus_Description=None, MaritalStatus_Description=None, US_Congressional_District='1', AddressDistricts_Change_Changed_CD='Has Not Changed Within Last 2 Years', State_Senate_District='B', AddressDistricts_Change_Changed_SD='Has Not Changed Within Last 2 Years', State_House_District='04', AddressDistricts_Change_Changed_HD='Has Not Changed Within Last 2 Years', State_Legislative_District=None, AddressDistricts_Change_Changed_LD=None, 2001_US_Congressional_District=None, 2001_State_Senate_District='D', 2001_State_House_District='07', 2001_State_Legislative_District=None, County='FAIRBANKS NORTH STAR', Voters_FIPS='090', AddressDistricts_Change_Changed_County='Has Not Changed Within Last 2 Years', Precinct='FARMERS LOOP (04-240)', County_Commissioner_District=None, County_Supervisorial_District=None, County_Legislative_District=None, City=None, City_Council_Commissioner_District=None, City_Ward=None, City_Mayoral_District=None, Town_District=None, Town_War ...
#  Row(SEQUENCE='275354', LALVOTERID='LALAK176753420', Voters_Active='A', Voters_StateVoterID='00022680', Voters_CountyVoterID=None, VoterTelephones_LandlineAreaCode=None, VoterTelephones_Landline7Digit=None, VoterTelephones_LandlineFormatted=None, VoterTelephones_LandlineUnformatted=None, VoterTelephones_LandlineConfidenceCode=None, VoterTelephones_CellPhoneOnly=None, VoterTelephones_CellPhoneFormatted=None, VoterTelephones_CellPhoneUnformatted=None, VoterTelephones_CellConfidenceCode=None, Voters_FirstName='Carol', Voters_MiddleName='A C', Voters_LastName='Norton', Voters_NameSuffix=None, Residence_Addresses_AddressLine='1749 Red Fox Dr', Residence_Addresses_ExtraAddressLine=None, Residence_Addresses_City='Fairbanks', Residence_Addresses_State='AK', Residence_Addresses_Zip='99709', Residence_Addresses_ZipPlus4='6666', Residence_Addresses_HouseNumber='1749', Residence_Addresses_PrefixDirection=None, Residence_Addresses_StreetName='Red Fox', Residence_Addresses_Designator='Dr', Residence_Addresses_SuffixDirection=None, Residence_Addresses_ApartmentNum=None, Residence_Addresses_ApartmentType=None, Residence_Addresses_CassErrStatCode='S80000', Voters_SequenceZigZag='275354', Voters_SequenceOddEven='275364', Residence_Addresses_CensusTract='001300', Residence_Addresses_CensusBlockGroup='3', Residence_Addresses_CensusBlock='3011', Residence_Addresses_Latitude='64.901750', Residence_Addresses_Longitude='-147.816920', Residence_Addresses_LatLongAccuracy='GeoMatchRooftop', Residence_Addresses_Property_LandSq_Footage='0172000', Residence_Addresses_Property_HomeSq_Footage='03600', Residence_Addresses_Density='264', Residence_Families_FamilyID='R000242223', Residence_Families_HHCount='3', Residence_HHGender_Description='Mixed Gender Household', Residence_HHParties_Description='Independent', Mailing_Addresses_AddressLine='1749 Red Fox Dr', Mailing_Addresses_ExtraAddressLine=None, Mailing_Addresses_City='Fairbanks', Mailing_Addresses_State='AK', Mailing_Addresses_Zip='99709', Mailing_Addresses_ZipPlus4='6666', Mailing_Addresses_HouseNumber='1749', Mailing_Addresses_PrefixDirection=None, Mailing_Addresses_StreetName='Red Fox', Mailing_Addresses_Designator='Dr', Mailing_Addresses_SuffixDirection=None, Mailing_Addresses_ApartmentNum=None, Mailing_Addresses_ApartmentType=None, Mailing_Addresses_CassErrStatCode='S80000', Mailing_Families_FamilyID='M000242223', Mailing_Families_HHCount='3', Mailing_HHGender_Description='Mixed Gender Household', Mailing_HHParties_Description='Independent', Voters_Gender='F', Voters_Age='76', Voters_BirthDate='05/25/1945', DateConfidence_Description='Complete Date', Parties_Description='Unknown', VoterParties_Change_Changed_Party=None, Ethnic_Description='English/Welsh', EthnicGroups_EthnicGroup1Desc='European', CountyEthnic_LALEthnicCode=None, CountyEthnic_Description=None, Religions_Description='Protestant', Voters_CalculatedRegDate='08/27/1968', Voters_OfficialRegDate='07/12/2020', Voters_PlaceOfBirth=None, Languages_Description='English', AbsenteeTypes_Description=None, MilitaryStatus_Description=None, MaritalStatus_Description='Married', US_Congressional_District='1', AddressDistricts_Change_Changed_CD='Has Not Changed Within Last 2 Years', State_Senate_District='B', AddressDistricts_Change_Changed_SD='Has Not Changed Within Last 2 Years', State_House_District='04', AddressDistricts_Change_Changed_HD='Has Not Changed Within Last 2 Years', State_Legislative_District=None, AddressDistricts_Change_Changed_LD=None, 2001_US_Congressional_District=None, 2001_State_Senate_District='D', 2001_State_House_District='07', 2001_State_Legislative_District=None, County='FAIRBANKS NORTH STAR', Voters_FIPS='090', AddressDistricts_Change_Changed_County='Has Not Changed Within Last 2 Years', Precinct='FARMERS LOOP (04-240)', County_Commissioner_District=None, County_Supervisorial_District=None, County_Legislative_District=None, City=None, City_Council_Commissioner_District=None, City_Ward=None, City_Mayoral_District=None, Town_D ...
#  Row(SEQUENCE='275355', LALVOTERID='LALAK176753423', Voters_Active='A', Voters_StateVoterID='00022682', Voters_CountyVoterID=None, VoterTelephones_LandlineAreaCode=None, VoterTelephones_Landline7Digit=None, VoterTelephones_LandlineFormatted=None, VoterTelephones_LandlineUnformatted=None, VoterTelephones_LandlineConfidenceCode=None, VoterTelephones_CellPhoneOnly=None, VoterTelephones_CellPhoneFormatted=None, VoterTelephones_CellPhoneUnformatted=None, VoterTelephones_CellConfidenceCode=None, Voters_FirstName='David', Voters_MiddleName='William', Voters_LastName='Norton', Voters_NameSuffix=None, Residence_Addresses_AddressLine='1749 Red Fox Dr', Residence_Addresses_ExtraAddressLine=None, Residence_Addresses_City='Fairbanks', Residence_Addresses_State='AK', Residence_Addresses_Zip='99709', Residence_Addresses_ZipPlus4='6666', Residence_Addresses_HouseNumber='1749', Residence_Addresses_PrefixDirection=None, Residence_Addresses_StreetName='Red Fox', Residence_Addresses_Designator='Dr', Residence_Addresses_SuffixDirection=None, Residence_Addresses_ApartmentNum=None, Residence_Addresses_ApartmentType=None, Residence_Addresses_CassErrStatCode='S80000', Voters_SequenceZigZag='275353', Voters_SequenceOddEven='275363', Residence_Addresses_CensusTract='001300', Residence_Addresses_CensusBlockGroup='3', Residence_Addresses_CensusBlock='3011', Residence_Addresses_Latitude='64.901750', Residence_Addresses_Longitude='-147.816920', Residence_Addresses_LatLongAccuracy='GeoMatchRooftop', Residence_Addresses_Property_LandSq_Footage='0172000', Residence_Addresses_Property_HomeSq_Footage='03600', Residence_Addresses_Density='264', Residence_Families_FamilyID='R000242223', Residence_Families_HHCount='3', Residence_HHGender_Description='Mixed Gender Household', Residence_HHParties_Description='Independent', Mailing_Addresses_AddressLine='1749 Red Fox Dr', Mailing_Addresses_ExtraAddressLine=None, Mailing_Addresses_City='Fairbanks', Mailing_Addresses_State='AK', Mailing_Addresses_Zip='99709', Mailing_Addresses_ZipPlus4='6666', Mailing_Addresses_HouseNumber='1749', Mailing_Addresses_PrefixDirection=None, Mailing_Addresses_StreetName='Red Fox', Mailing_Addresses_Designator='Dr', Mailing_Addresses_SuffixDirection=None, Mailing_Addresses_ApartmentNum=None, Mailing_Addresses_ApartmentType=None, Mailing_Addresses_CassErrStatCode='S80000', Mailing_Families_FamilyID='M000242223', Mailing_Families_HHCount='3', Mailing_HHGender_Description='Mixed Gender Household', Mailing_HHParties_Description='Independent', Voters_Gender='M', Voters_Age='77', Voters_BirthDate='03/04/1944', DateConfidence_Description='Complete Date', Parties_Description='Unknown', VoterParties_Change_Changed_Party=None, Ethnic_Description='English/Welsh', EthnicGroups_EthnicGroup1Desc='European', CountyEthnic_LALEthnicCode=None, CountyEthnic_Description=None, Religions_Description='Protestant', Voters_CalculatedRegDate='08/27/1968', Voters_OfficialRegDate='07/12/2020', Voters_PlaceOfBirth=None, Languages_Description='English', AbsenteeTypes_Description=None, MilitaryStatus_Description=None, MaritalStatus_Description='Married', US_Congressional_District='1', AddressDistricts_Change_Changed_CD='Has Not Changed Within Last 2 Years', State_Senate_District='B', AddressDistricts_Change_Changed_SD='Has Not Changed Within Last 2 Years', State_House_District='04', AddressDistricts_Change_Changed_HD='Has Not Changed Within Last 2 Years', State_Legislative_District=None, AddressDistricts_Change_Changed_LD=None, 2001_US_Congressional_District=None, 2001_State_Senate_District='D', 2001_State_House_District='07', 2001_State_Legislative_District=None, County='FAIRBANKS NORTH STAR', Voters_FIPS='090', AddressDistricts_Change_Changed_County='Has Not Changed Within Last 2 Years', Precinct='FARMERS LOOP (04-240)', County_Commissioner_District=None, County_Supervisorial_District=None, County_Legislative_District=None, City=None, City_Council_Commissioner_District=None, City_Ward=None, City_Mayoral_District=None, To ...
#  Row(SEQUENCE='275356', LALVOTERID='LALAK176884699', Voters_Active='A', Voters_StateVoterID='00526677', Voters_CountyVoterID=None, VoterTelephones_LandlineAreaCode=None, VoterTelephones_Landline7Digit=None, VoterTelephones_LandlineFormatted=None, VoterTelephones_LandlineUnformatted=None, VoterTelephones_LandlineConfidenceCode=None, VoterTelephones_CellPhoneOnly=None, VoterTelephones_CellPhoneFormatted=None, VoterTelephones_CellPhoneUnformatted=None, VoterTelephones_CellConfidenceCode=None, Voters_FirstName='Kerry', Voters_MiddleName='Lynn', Voters_LastName='Norton', Voters_NameSuffix=None, Residence_Addresses_AddressLine='1749 Red Fox Dr', Residence_Addresses_ExtraAddressLine=None, Residence_Addresses_City='Fairbanks', Residence_Addresses_State='AK', Residence_Addresses_Zip='99709', Residence_Addresses_ZipPlus4='6666', Residence_Addresses_HouseNumber='1749', Residence_Addresses_PrefixDirection=None, Residence_Addresses_StreetName='Red Fox', Residence_Addresses_Designator='Dr', Residence_Addresses_SuffixDirection=None, Residence_Addresses_ApartmentNum=None, Residence_Addresses_ApartmentType=None, Residence_Addresses_CassErrStatCode='S80000', Voters_SequenceZigZag='275355', Voters_SequenceOddEven='275365', Residence_Addresses_CensusTract='001300', Residence_Addresses_CensusBlockGroup='3', Residence_Addresses_CensusBlock='3011', Residence_Addresses_Latitude='64.901750', Residence_Addresses_Longitude='-147.816920', Residence_Addresses_LatLongAccuracy='GeoMatchRooftop', Residence_Addresses_Property_LandSq_Footage='0172000', Residence_Addresses_Property_HomeSq_Footage='03600', Residence_Addresses_Density='264', Residence_Families_FamilyID='R000242223', Residence_Families_HHCount='3', Residence_HHGender_Description='Mixed Gender Household', Residence_HHParties_Description='Independent', Mailing_Addresses_AddressLine='1749 Red Fox Dr', Mailing_Addresses_ExtraAddressLine=None, Mailing_Addresses_City='Fairbanks', Mailing_Addresses_State='AK', Mailing_Addresses_Zip='99709', Mailing_Addresses_ZipPlus4='6666', Mailing_Addresses_HouseNumber='1749', Mailing_Addresses_PrefixDirection=None, Mailing_Addresses_StreetName='Red Fox', Mailing_Addresses_Designator='Dr', Mailing_Addresses_SuffixDirection=None, Mailing_Addresses_ApartmentNum=None, Mailing_Addresses_ApartmentType=None, Mailing_Addresses_CassErrStatCode='S80000', Mailing_Families_FamilyID='M000242223', Mailing_Families_HHCount='3', Mailing_HHGender_Description='Mixed Gender Household', Mailing_HHParties_Description='Independent', Voters_Gender='F', Voters_Age='48', Voters_BirthDate='03/20/1973', DateConfidence_Description='Complete Date', Parties_Description='Unknown', VoterParties_Change_Changed_Party=None, Ethnic_Description='English/Welsh', EthnicGroups_EthnicGroup1Desc='European', CountyEthnic_LALEthnicCode=None, CountyEthnic_Description=None, Religions_Description=None, Voters_CalculatedRegDate='02/13/1992', Voters_OfficialRegDate='10/03/2020', Voters_PlaceOfBirth=None, Languages_Description=None, AbsenteeTypes_Description=None, MilitaryStatus_Description=None, MaritalStatus_Description=None, US_Congressional_District='1', AddressDistricts_Change_Changed_CD='Has Not Changed Within Last 2 Years', State_Senate_District='B', AddressDistricts_Change_Changed_SD='Has Not Changed Within Last 2 Years', State_House_District='04', AddressDistricts_Change_Changed_HD='Has Not Changed Within Last 2 Years', State_Legislative_District=None, AddressDistricts_Change_Changed_LD=None, 2001_US_Congressional_District=None, 2001_State_Senate_District='D', 2001_State_House_District='07', 2001_State_Legislative_District=None, County='FAIRBANKS NORTH STAR', Voters_FIPS='090', AddressDistricts_Change_Changed_County='Has Not Changed Within Last 2 Years', Precinct='FARMERS LOOP (04-240)', County_Commissioner_District=None, County_Supervisorial_District=None, County_Legislative_District=None, City=None, City_Council_Commissioner_District=None, City_Ward=None, City_Mayoral_District=None, Town_District=None, Tow ...
# ...
#  Row(SEQUENCE='275363', LALVOTERID='LALAK177052652', Voters_Active='A', Voters_StateVoterID='00887534', Voters_CountyVoterID=None, VoterTelephones_LandlineAreaCode='713', VoterTelephones_Landline7Digit='326-1818', VoterTelephones_LandlineFormatted='(713) 326-1818', VoterTelephones_LandlineUnformatted='7133261818', VoterTelephones_LandlineConfidenceCode='2', VoterTelephones_CellPhoneOnly=None, VoterTelephones_CellPhoneFormatted=None, VoterTelephones_CellPhoneUnformatted=None, VoterTelephones_CellConfidenceCode=None, Voters_FirstName='Keiko', Voters_MiddleName='A', Voters_LastName='Herrick', Voters_NameSuffix=None, Residence_Addresses_AddressLine='1790 Red Fox Dr', Residence_Addresses_ExtraAddressLine=None, Residence_Addresses_City='Fairbanks', Residence_Addresses_State='AK', Residence_Addresses_Zip='99709', Residence_Addresses_ZipPlus4='6665', Residence_Addresses_HouseNumber='1790', Residence_Addresses_PrefixDirection=None, Residence_Addresses_StreetName='Red Fox', Residence_Addresses_Designator='Dr', Residence_Addresses_SuffixDirection=None, Residence_Addresses_ApartmentNum=None, Residence_Addresses_ApartmentType=None, Residence_Addresses_CassErrStatCode='S80000', Voters_SequenceZigZag='275363', Voters_SequenceOddEven='275352', Residence_Addresses_CensusTract='001300', Residence_Addresses_CensusBlockGroup='3', Residence_Addresses_CensusBlock='3000', Residence_Addresses_Latitude='64.902660', Residence_Addresses_Longitude='-147.822830', Residence_Addresses_LatLongAccuracy='GeoMatchRooftop', Residence_Addresses_Property_LandSq_Footage='0178000', Residence_Addresses_Property_HomeSq_Footage='03500', Residence_Addresses_Density='436', Residence_Families_FamilyID='R001116947', Residence_Families_HHCount='2', Residence_HHGender_Description='Mixed Gender Household', Residence_HHParties_Description='Republican & Independent', Mailing_Addresses_AddressLine='1790 Red Fox Dr', Mailing_Addresses_ExtraAddressLine=None, Mailing_Addresses_City='Fairbanks', Mailing_Addresses_State='AK', Mailing_Addresses_Zip='99709', Mailing_Addresses_ZipPlus4='6665', Mailing_Addresses_HouseNumber='1790', Mailing_Addresses_PrefixDirection=None, Mailing_Addresses_StreetName='Red Fox', Mailing_Addresses_Designator='Dr', Mailing_Addresses_SuffixDirection=None, Mailing_Addresses_ApartmentNum=None, Mailing_Addresses_ApartmentType=None, Mailing_Addresses_CassErrStatCode='S80000', Mailing_Families_FamilyID='M001116947', Mailing_Families_HHCount='2', Mailing_HHGender_Description='Mixed Gender Household', Mailing_HHParties_Description='Republican & Independent', Voters_Gender='F', Voters_Age='52', Voters_BirthDate='01/01/1969', DateConfidence_Description='Valid Year', Parties_Description='Unknown', VoterParties_Change_Changed_Party=None, Ethnic_Description='Japanese', EthnicGroups_EthnicGroup1Desc='East and South Asian', CountyEthnic_LALEthnicCode=None, CountyEthnic_Description=None, Religions_Description=None, Voters_CalculatedRegDate='06/17/2003', Voters_OfficialRegDate='08/06/2020', Voters_PlaceOfBirth=None, Languages_Description=None, AbsenteeTypes_Description=None, MilitaryStatus_Description=None, MaritalStatus_Description='Married', US_Congressional_District='1', AddressDistricts_Change_Changed_CD='Has Not Changed Within Last 2 Years', State_Senate_District='B', AddressDistricts_Change_Changed_SD='Has Not Changed Within Last 2 Years', State_House_District='04', AddressDistricts_Change_Changed_HD='Has Not Changed Within Last 2 Years', State_Legislative_District=None, AddressDistricts_Change_Changed_LD=None, 2001_US_Congressional_District=None, 2001_State_Senate_District='D', 2001_State_House_District='07', 2001_State_Legislative_District=None, County='FAIRBANKS NORTH STAR', Voters_FIPS='090', AddressDistricts_Change_Changed_County='Has Not Changed Within Last 2 Years', Precinct='FARMERS LOOP (04-240)', County_Commissioner_District=None, County_Supervisorial_District=None, County_Legislative_District=None, City=None, City_Council_Commissioner_District=None, City_War ...
#  Row(SEQUENCE='275364', LALVOTERID='LALAK177050344', Voters_Active='A', Voters_StateVoterID='00914545', Voters_CountyVoterID=None, VoterTelephones_LandlineAreaCode='713', VoterTelephones_Landline7Digit='326-1818', VoterTelephones_LandlineFormatted='(713) 326-1818', VoterTelephones_LandlineUnformatted='7133261818', VoterTelephones_LandlineConfidenceCode='2', VoterTelephones_CellPhoneOnly=None, VoterTelephones_CellPhoneFormatted='(907) 750-9649', VoterTelephones_CellPhoneUnformatted='9077509649', VoterTelephones_CellConfidenceCode='1', Voters_FirstName='Robert', Voters_MiddleName='Ritchie', Voters_LastName='Herrick', Voters_NameSuffix=None, Residence_Addresses_AddressLine='1790 Red Fox Dr', Residence_Addresses_ExtraAddressLine=None, Residence_Addresses_City='Fairbanks', Residence_Addresses_State='AK', Residence_Addresses_Zip='99709', Residence_Addresses_ZipPlus4='6665', Residence_Addresses_HouseNumber='1790', Residence_Addresses_PrefixDirection=None, Residence_Addresses_StreetName='Red Fox', Residence_Addresses_Designator='Dr', Residence_Addresses_SuffixDirection=None, Residence_Addresses_ApartmentNum=None, Residence_Addresses_ApartmentType=None, Residence_Addresses_CassErrStatCode='S80000', Voters_SequenceZigZag='275362', Voters_SequenceOddEven='275351', Residence_Addresses_CensusTract='001300', Residence_Addresses_CensusBlockGroup='3', Residence_Addresses_CensusBlock='3000', Residence_Addresses_Latitude='64.902660', Residence_Addresses_Longitude='-147.822830', Residence_Addresses_LatLongAccuracy='GeoMatchRooftop', Residence_Addresses_Property_LandSq_Footage='0178000', Residence_Addresses_Property_HomeSq_Footage='03500', Residence_Addresses_Density='436', Residence_Families_FamilyID='R001116947', Residence_Families_HHCount='2', Residence_HHGender_Description='Mixed Gender Household', Residence_HHParties_Description='Republican & Independent', Mailing_Addresses_AddressLine='1790 Red Fox Dr', Mailing_Addresses_ExtraAddressLine=None, Mailing_Addresses_City='Fairbanks', Mailing_Addresses_State='AK', Mailing_Addresses_Zip='99709', Mailing_Addresses_ZipPlus4='6665', Mailing_Addresses_HouseNumber='1790', Mailing_Addresses_PrefixDirection=None, Mailing_Addresses_StreetName='Red Fox', Mailing_Addresses_Designator='Dr', Mailing_Addresses_SuffixDirection=None, Mailing_Addresses_ApartmentNum=None, Mailing_Addresses_ApartmentType=None, Mailing_Addresses_CassErrStatCode='S80000', Mailing_Families_FamilyID='M001116947', Mailing_Families_HHCount='2', Mailing_HHGender_Description='Mixed Gender Household', Mailing_HHParties_Description='Republican & Independent', Voters_Gender='M', Voters_Age='57', Voters_BirthDate='06/12/1964', DateConfidence_Description='Complete Date', Parties_Description='Republican', VoterParties_Change_Changed_Party=None, Ethnic_Description='English/Welsh', EthnicGroups_EthnicGroup1Desc='European', CountyEthnic_LALEthnicCode=None, CountyEthnic_Description=None, Religions_Description=None, Voters_CalculatedRegDate='07/24/2004', Voters_OfficialRegDate='09/28/2020', Voters_PlaceOfBirth=None, Languages_Description='English', AbsenteeTypes_Description=None, MilitaryStatus_Description=None, MaritalStatus_Description='Married', US_Congressional_District='1', AddressDistricts_Change_Changed_CD='Has Not Changed Within Last 2 Years', State_Senate_District='B', AddressDistricts_Change_Changed_SD='Has Not Changed Within Last 2 Years', State_House_District='04', AddressDistricts_Change_Changed_HD='Has Not Changed Within Last 2 Years', State_Legislative_District=None, AddressDistricts_Change_Changed_LD=None, 2001_US_Congressional_District=None, 2001_State_Senate_District='D', 2001_State_House_District='07', 2001_State_Legislative_District=None, County='FAIRBANKS NORTH STAR', Voters_FIPS='090', AddressDistricts_Change_Changed_County='Has Not Changed Within Last 2 Years', Precinct='FARMERS LOOP (04-240)', County_Commissioner_District=None, County_Supervisorial_District=None, County_Legislative_District=None, City=None, City_Council_Commis ...
#  Row(SEQUENCE='275365', LALVOTERID='LALAK176841101', Voters_Active='A', Voters_StateVoterID='00401180', Voters_CountyVoterID=None, VoterTelephones_LandlineAreaCode=None, VoterTelephones_Landline7Digit=None, VoterTelephones_LandlineFormatted=None, VoterTelephones_LandlineUnformatted=None, VoterTelephones_LandlineConfidenceCode=None, VoterTelephones_CellPhoneOnly=None, VoterTelephones_CellPhoneFormatted=None, VoterTelephones_CellPhoneUnformatted=None, VoterTelephones_CellConfidenceCode=None, Voters_FirstName='Syun-Ichi', Voters_MiddleName=None, Voters_LastName='Akasofu', Voters_NameSuffix=None, Residence_Addresses_AddressLine='1802 Red Fox Dr Apt 26', Residence_Addresses_ExtraAddressLine=None, Residence_Addresses_City='Fairbanks', Residence_Addresses_State='AK', Residence_Addresses_Zip='99709', Residence_Addresses_ZipPlus4='6624', Residence_Addresses_HouseNumber='1802', Residence_Addresses_PrefixDirection=None, Residence_Addresses_StreetName='Red Fox', Residence_Addresses_Designator='Dr', Residence_Addresses_SuffixDirection=None, Residence_Addresses_ApartmentNum='26', Residence_Addresses_ApartmentType='Apt', Residence_Addresses_CassErrStatCode='S80000', Voters_SequenceZigZag='275364', Voters_SequenceOddEven='275353', Residence_Addresses_CensusTract='001300', Residence_Addresses_CensusBlockGroup='3', Residence_Addresses_CensusBlock='3000', Residence_Addresses_Latitude='64.901979', Residence_Addresses_Longitude='-147.823380', Residence_Addresses_LatLongAccuracy='GeoMatchRooftop', Residence_Addresses_Property_LandSq_Footage='0134000', Residence_Addresses_Property_HomeSq_Footage=None, Residence_Addresses_Density='436', Residence_Families_FamilyID='R000231980', Residence_Families_HHCount='1', Residence_HHGender_Description='Male Only Household', Residence_HHParties_Description='Independent', Mailing_Addresses_AddressLine='PO Box 83175', Mailing_Addresses_ExtraAddressLine=None, Mailing_Addresses_City='Fairbanks', Mailing_Addresses_State='AK', Mailing_Addresses_Zip='99708', Mailing_Addresses_ZipPlus4='3175', Mailing_Addresses_HouseNumber=None, Mailing_Addresses_PrefixDirection=None, Mailing_Addresses_StreetName='PO Box 83175', Mailing_Addresses_Designator=None, Mailing_Addresses_SuffixDirection=None, Mailing_Addresses_ApartmentNum=None, Mailing_Addresses_ApartmentType=None, Mailing_Addresses_CassErrStatCode='S80000', Mailing_Families_FamilyID='M001409579', Mailing_Families_HHCount='2', Mailing_HHGender_Description='Mixed Gender Household', Mailing_HHParties_Description='Independent', Voters_Gender='M', Voters_Age='91', Voters_BirthDate='12/04/1930', DateConfidence_Description='Complete Date', Parties_Description='Unknown', VoterParties_Change_Changed_Party=None, Ethnic_Description=None, EthnicGroups_EthnicGroup1Desc=None, CountyEthnic_LALEthnicCode=None, CountyEthnic_Description=None, Religions_Description='Christian', Voters_CalculatedRegDate='12/05/1986', Voters_OfficialRegDate='09/22/2020', Voters_PlaceOfBirth=None, Languages_Description=None, AbsenteeTypes_Description=None, MilitaryStatus_Description=None, MaritalStatus_Description=None, US_Congressional_District='1', AddressDistricts_Change_Changed_CD='Has Not Changed Within Last 2 Years', State_Senate_District='B', AddressDistricts_Change_Changed_SD='Has Not Changed Within Last 2 Years', State_House_District='04', AddressDistricts_Change_Changed_HD='Has Not Changed Within Last 2 Years', State_Legislative_District=None, AddressDistricts_Change_Changed_LD=None, 2001_US_Congressional_District=None, 2001_State_Senate_District='D', 2001_State_House_District='07', 2001_State_Legislative_District=None, County='FAIRBANKS NORTH STAR', Voters_FIPS='090', AddressDistricts_Change_Changed_County='Has Not Changed Within Last 2 Years', Precinct='FARMERS LOOP (04-240)', County_Commissioner_District=None, County_Supervisorial_District=None, County_Legislative_District=None, City=None, City_Council_Commissioner_District=None, City_Ward=None, City_Mayoral_District=None, Town_District=None, Town_War ...

# %% [markdown]
# The notebook is running on my machine's default runtime in 'us-west1', we can connect to an external runtime for quicker results.
#
# With the "Open Job" page, we see the much longer SQL query that is running behind the scenes, and we can see the execution details and chart like in the last BigQuery exercise.
